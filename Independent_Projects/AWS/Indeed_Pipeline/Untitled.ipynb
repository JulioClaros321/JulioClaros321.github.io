# %%
import pyautogui
import time 
import sys
import requests
#5dAbkYdbaCUkPZr949WpXpntf0NjRWrBFr9Lz9Ib
#T 12460590
#IDK12458104

# %%
url = 'https://api.printful.com/products/438' # Replace 'specific_endpoint' with the actual endpoint
headers = {'Authorization': 'Bearer 5dAbkYdbaCUkPZr949WpXpntf0NjRWrBFr9Lz9Ib'}  # Replace with your actual API token



response = requests.get(url, headers=headers)  # Include ', data=data' if you have data to send

if response.status_code == 200:
    print("Success:")
    print(response.json())
else:
    print("Failed with status code:", response.status_code)
    print(response.text)
# Out:
# Success:
# ...

# %%
url = "https://api.printful.com/store/products"
headers = {"Authorization": "Bearer 5dAbkYdbaCUkPZr949WpXpntf0NjRWrBFr9Lz9Ib"}
data = {
    "product": {
        "variant_id": 111,  # Replace with the actual variant ID from Printful's catalog
        "files": [{
            "type": "default",
            "url": "http://example.com/your-design.png"  # URL to your design file
        }],
        # Add other product details as needed
    }
}

response = requests.post(url, json=data, headers=headers)
print(response.json())

# %%
curl --location --request GET 'https://api.printful.com/categories' \
--header 'Authorization: Bearer {your_token}'

# %%
#Men’s Classic Tee | Gildan 5000
#Men's Premium Heavyweight Tee | Cotton Heritage MC1086
#Unisex Crew Neck Sweatshirt | Gildan 18000
#Unisex Premium Sweatshirt | Cotton Heritage M2480
#Women's Relaxed T-Shirt | Bella + Canvas 6400
#Women's Fashion Fit T-Shirt | Gildan 880

# %%
#MENS CLASSIC TEE
