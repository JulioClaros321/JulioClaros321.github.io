# %%
import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot

from scipy import stats
from statistics import stdev
from collections import Counter

from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %matplotlib inline

# %%
student_data = pd.read_csv("student_education_data.csv")
print(sklearn.__version__)
# Out:
# 1.0.2

# %%
student_data
# Out:
#     Gender Nationality PlaceofBirth        StageID GradeID SectionID  \
# 0        M      Kuwait       Kuwait  PrimarySchool    G-04         A
# 1        M      Kuwait       Kuwait  PrimarySchool    G-04         A
# 2        M      Kuwait       Kuwait  PrimarySchool    G-04         A
# 3        M      Kuwait       Kuwait  PrimarySchool    G-04         A
# 4        M      Kuwait       Kuwait  PrimarySchool    G-04         A
# ..     ...         ...          ...            ...     ...       ...
# 475      F      Jordan       Jordan   MiddleSchool    G-08         A
# 476      F      Jordan       Jordan   MiddleSchool    G-08         A
# 477      F      Jordan       Jordan   MiddleSchool    G-08         A
# 478      F      Jordan       Jordan   MiddleSchool    G-08         A
# 479      F      Jordan       Jordan   MiddleSchool    G-08         A
#
#          Topic Semester PrimaryGuardian  RaisedHand  VisitedResources  \
# 0           IT        F          Father          15                16
# 1           IT        F          Father          20                20
# 2           IT        F          Father          10                 7
# 3           IT        F          Father          30                25
# 4           IT        F          Father          40                50
# ..         ...      ...             ...         ...               ...
# 475  Chemistry        S          Father           5                 4
# 476    Geology        F          Father          50                77
# 477    Geology        S          Father          55                74
# 478    History        F          Father          30                17
# 479    History        S          Father          35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 0                    2          20                   Yes
# 1                    3          25                   Yes
# 2                    0          30                    No
# 3                    5          35                    No
# 4                   12          50                    No
# ..                 ...         ...                   ...
# 475                  5           8                    No
# 476                 14          28                    No
# 477                 25          29                    No
# 478                 14          57                    No
# 479                 23          62                    No
#
#     ParentSchoolSatisfaction StudentAbsenceDays    Performance
# 0                       Good            Under-7        Average
# 1                       Good            Under-7        Average
# 2                        Bad            Above-7  Below Average
# 3                        Bad            Above-7  Below Average
# 4                        Bad            Above-7        Average
# ..                       ...                ...            ...
# 475                      Bad            Above-7  Below Average
# 476                      Bad            Under-7        Average
# 477                      Bad            Under-7        Average
# 478                      Bad            Above-7  Below Average
# 479                      Bad            Above-7  Below Average
#
# [480 rows x 17 columns]

# %%
'''Students from Kuwait and Jordan birthplaces made a majority of the students, will serve as our sample populations'''

Kuwait_Students = student_data.loc[student_data["PlaceofBirth"]=="Kuwait"]
Kuwait_Students
# Out:
#     Gender Nationality PlaceofBirth        StageID GradeID SectionID    Topic  \
# 0        M      Kuwait       Kuwait  PrimarySchool    G-04         A       IT
# 1        M      Kuwait       Kuwait  PrimarySchool    G-04         A       IT
# 2        M      Kuwait       Kuwait  PrimarySchool    G-04         A       IT
# 3        M      Kuwait       Kuwait  PrimarySchool    G-04         A       IT
# 4        M      Kuwait       Kuwait  PrimarySchool    G-04         A       IT
# ..     ...         ...          ...            ...     ...       ...      ...
# 258      F      Kuwait       Kuwait  PrimarySchool    G-04         A  History
# 259      M      Kuwait       Kuwait  PrimarySchool    G-04         A  English
# 260      M      Kuwait       Kuwait  PrimarySchool    G-04         A  History
# 261      M      Kuwait       Kuwait  PrimarySchool    G-04         A  History
# 262      F      Kuwait       Kuwait  PrimarySchool    G-04         A  History
#
#     Semester PrimaryGuardian  RaisedHand  VisitedResources  AnnouncementsView  \
# 0          F          Father          15                16                  2
# 1          F          Father          20                20                  3
# 2          F          Father          10                 7                  0
# 3          F          Father          30                25                  5
# 4          F          Father          40                50                 12
# ..       ...             ...         ...               ...                ...
# 258        S          Father          80                97                 86
# 259        S          Mother          69                34                 12
# 260        S          Father          10                17                 12
# 261        S          Father          61                97                 82
# 262        S          Mother          21                27                 52
#
#      Discussion ParentAnsweringSurvey ParentSchoolSatisfaction  \
# 0            20                   Yes                     Good
# 1            25                   Yes                     Good
# 2            30                    No                      Bad
# 3            35                    No                      Bad
# 4            50                    No                      Bad
# ..          ...                   ...                      ...
# 258          95                   Yes                     Good
# 259          17                    No                      Bad
# 260          14                    No                      Bad
# 261          64                   Yes                      Bad
# 262          34                   Yes                     Good
#
#     StudentAbsenceDays    Performance
# 0              Under-7        Average
# 1              Under-7        Average
# 2              Above-7  Below Average
# 3              Above-7  Below Average
# 4              Above-7        Average
# ..                 ...            ...
# 258            Under-7        Average
# 259            Above-7  Below Average
# 260            Above-7  Below Average
# 261            Above-7        Average
# 262            Above-7        Average
#
# [180 rows x 17 columns]

# %%
student_data.describe()
# Out:
#        RaisedHand  VisitedResources  AnnouncementsView  Discussion
# count  480.000000        480.000000         480.000000  480.000000
# mean    46.775000         54.797917          37.918750   43.283333
# std     30.779223         33.080007          26.611244   27.637735
# min      0.000000          0.000000           0.000000    1.000000
# 25%     15.750000         20.000000          14.000000   20.000000
# 50%     50.000000         65.000000          33.000000   39.000000
# 75%     75.000000         84.000000          58.000000   70.000000
# max    100.000000         99.000000          98.000000   99.000000

# %%
'''Grab total Number of Kuwait students'''

len(Kuwait_Students)
# Out:
# 180

# %%
'''School Age Group as categorization of students'''

Kuwait_StudentsPrimary = Kuwait_Students.loc[Kuwait_Students["StageID"]=="PrimarySchool"]
Kuwait_StudentsMiddle = Kuwait_Students.loc[Kuwait_Students["StageID"]=="MiddleSchool"]
Kuwait_StudentsHigh = Kuwait_Students.loc[Kuwait_Students["StageID"]=="Highschool"]

# %%
'''Unique command to see how many unique subjects consisted within the groups of students'''

Kuwait_StudentsPrimary["Topic"].unique()
# Out:
# array(['IT', 'English', 'French', 'Math', 'Science', 'Arabic', 'History'],
#       dtype=object)

# %%
'''Separated the data based of subjects/topic'''

it = Kuwait_StudentsPrimary.loc[Kuwait_StudentsPrimary["Topic"]=="IT"]

english = Kuwait_StudentsPrimary.loc[Kuwait_StudentsPrimary["Topic"]=="English"]

math = Kuwait_StudentsPrimary.loc[Kuwait_StudentsPrimary["Topic"]=="Math"]

science = Kuwait_StudentsPrimary.loc[Kuwait_StudentsPrimary["Topic"]=="Science"] 

history = Kuwait_StudentsPrimary.loc[Kuwait_StudentsPrimary["Topic"]=="History"]

# %%
'''Grabbing Section of students with highest sample size, also only really concerned with IT subject regardless'''

print(len(Kuwait_StudentsPrimary), len(it))
# Out:
# 73 54

# %%
it
# Out:
#     Gender Nationality PlaceofBirth        StageID GradeID SectionID Topic  \
# 0        M      Kuwait       Kuwait  PrimarySchool    G-04         A    IT
# 1        M      Kuwait       Kuwait  PrimarySchool    G-04         A    IT
# 2        M      Kuwait       Kuwait  PrimarySchool    G-04         A    IT
# 3        M      Kuwait       Kuwait  PrimarySchool    G-04         A    IT
# 4        M      Kuwait       Kuwait  PrimarySchool    G-04         A    IT
# 5        F      Kuwait       Kuwait  PrimarySchool    G-04         A    IT
# 12       M      Kuwait       Kuwait  PrimarySchool    G-04         A    IT
# 81       M      Kuwait       Kuwait  PrimarySchool    G-02         A    IT
# 82       M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 83       M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 84       M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 85       M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 87       M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 88       F      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 89       M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 90       M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 91       M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 92       F      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 94       F      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 95       F      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 96       F      Kuwait       Kuwait  PrimarySchool    G-02         C    IT
# 97       F      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 98       F      Kuwait       Kuwait  PrimarySchool    G-02         C    IT
# 99       M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 100      M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 101      F      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 102      F      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 103      M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 104      M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 105      F      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 106      F      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 107      M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 109      M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 111      M      Kuwait       Kuwait  PrimarySchool    G-02         C    IT
# 112      M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 113      M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 114      M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 115      M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 116      F      Kuwait       Kuwait  PrimarySchool    G-02         C    IT
# 117      F      Kuwait       Kuwait  PrimarySchool    G-02         C    IT
# 118      F      Kuwait       Kuwait  PrimarySchool    G-02         C    IT
# 119      M      Kuwait       Kuwait  PrimarySchool    G-02         C    IT
# 120      M      Kuwait       Kuwait  PrimarySchool    G-02         C    IT
# 121      M      Kuwait       Kuwait  PrimarySchool    G-02         C    IT
# 122      F      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 124      M      Kuwait       Kuwait  PrimarySchool    G-02         C    IT
# 125      M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 127      M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 128      M      Kuwait       Kuwait  PrimarySchool    G-02         C    IT
# 129      M      Kuwait       Kuwait  PrimarySchool    G-02         B    IT
# 130      F      Kuwait       Kuwait  PrimarySchool    G-02         C    IT
# 132      M      Kuwait       Kuwait  PrimarySchool    G-02         C    IT
# 133      M      Kuwait       Kuwait  PrimarySchool    G-02         A    IT
# 249      M      Kuwait       Kuwait  PrimarySchool    G-04         A    IT
#
#     Semester PrimaryGuardian  RaisedHand  VisitedResources  AnnouncementsView  \
# 0          F          Father          15                16                  2
# 1          F          Father          20                20                  3
# 2          F          Father          10                 7                  0
# 3          F          Father          30                25                  5
# 4          F          Father          40                50                 12
# 5          F          Father          42                30                 13
# 12         F          Father           5                 1                  0
# 81         F          Father           8                25                  1
# 82         F          Father           7                 5                  2
# 83         F          Father           7                 4                 10
# 84         F          Father          50                70                 50
# 85         F          Father           1                 0                  1
# 87         F          Father          19                70                  3
# 88         F          Father           3                12                  4
# 89         F          Father           5                20                  1
# 90         F          Father           4                 8                 10
# 91         F          Father          80                90                 55
# 92         F          Father          50                70                 19
# 94         F          Father          80                44                 35
# 95         F          Father         100                80                  2
# 96         F          Father          14                60                 11
# 97         F          Father           6                 2                 38
# 98         F          Father          10                 3                  0
# 99         F          Father          50                 7                  9
# 100        F          Father          50                90                 40
# 101        F          Mother          70                92                 50
# 102        F          Father           2                 6                  2
# 103        F          Father           1                 7                  6
# 104        F          Father           0                12                  3
# 105        F          Father           0                 0                  5
# 106        F          Father          12                26                  7
# 107        F          Father          70                90                 41
# 109        F          Father          90                70                 30
# 111        F          Father          77                80                 51
# 112        F          Father           2                 5                  3
# 113        F          Father          25                27                  0
# 114        F          Father          11                 2                  0
# 115        F          Father           0                 8                 11
# 116        F          Mother          77                80                 12
# 117        F          Mother          25                29                 40
# 118        F          Mother          24                35                 23
# 119        F          Father          60                60                  3
# 120        F          Mother          21                12                  0
# 121        F          Mother           0                 4                  8
# 122        F          Father          66                90                 55
# 124        F          Father           0                 6                  4
# 125        F          Father          12                30                  0
# 127        F          Father          55                33                  6
# 128        F          Father          12                10                 20
# 129        F          Father          70                90                  2
# 130        F          Father           7                 9                  5
# 132        S          Father           0                 3                 10
# 133        S          Father          12                60                  0
# 249        S          Father          65                86                 62
#
#      Discussion ParentAnsweringSurvey ParentSchoolSatisfaction  \
# 0            20                   Yes                     Good
# 1            25                   Yes                     Good
# 2            30                    No                      Bad
# 3            35                    No                      Bad
# 4            50                    No                      Bad
# 5            70                   Yes                      Bad
# 12           11                    No                      Bad
# 81           70                    No                      Bad
# 82           80                   Yes                     Good
# 83           50                    No                     Good
# 84           10                   Yes                     Good
# 85           12                    No                      Bad
# 87           50                    No                      Bad
# 88           33                    No                      Bad
# 89           50                   Yes                     Good
# 90           60                   Yes                     Good
# 91           19                   Yes                     Good
# 92           15                   Yes                     Good
# 94           10                    No                     Good
# 95           70                    No                      Bad
# 96           75                   Yes                     Good
# 97           12                    No                      Bad
# 98           30                    No                      Bad
# 99           50                   Yes                      Bad
# 100          90                   Yes                      Bad
# 101           7                   Yes                     Good
# 102           8                    No                      Bad
# 103          10                    No                      Bad
# 104           3                   Yes                     Good
# 105          80                   Yes                     Good
# 106          40                   Yes                     Good
# 107          33                   Yes                      Bad
# 109          14                    No                      Bad
# 111          80                    No                     Good
# 112          50                    No                      Bad
# 113          69                    No                      Bad
# 114          50                    No                      Bad
# 115          70                   Yes                     Good
# 116          19                   Yes                     Good
# 117          17                    No                     Good
# 118          22                   Yes                     Good
# 119          60                    No                      Bad
# 120          50                   Yes                     Good
# 121          30                    No                      Bad
# 122          12                   Yes                     Good
# 124          15                   Yes                      Bad
# 125          17                    No                     Good
# 127           9                    No                      Bad
# 128          16                    No                      Bad
# 129           2                   Yes                     Good
# 130          30                    No                      Bad
# 132           3                    No                      Bad
# 133          70                   Yes                     Good
# 249          40                    No                     Good
#
#     StudentAbsenceDays    Performance
# 0              Under-7        Average
# 1              Under-7        Average
# 2              Above-7  Below Average
# 3              Above-7  Below Average
# 4              Above-7        Average
# 5              Above-7        Average
# 12             Above-7  Below Average
# 81             Above-7  Below Average
# 82             Above-7  Below Average
# 83             Above-7        Average
# 84             Above-7  Above Average
# 85             Above-7  Below Average
# 87             Under-7  Below Average
# 88             Under-7  Below Average
# 89             Above-7  Below Average
# 90             Above-7  Below Average
# 91             Under-7  Above Average
# 92             Under-7  Above Average
# 94             Above-7  Below Average
# 95             Under-7  Above Average
# 96             Under-7  Above Average
# 97             Under-7        Average
# 98             Under-7        Average
# 99             Above-7        Average
# 100            Under-7        Average
# 101            Under-7  Above Average
# 102            Above-7  Below Average
# 103            Above-7  Below Average
# 104            Above-7        Average
# 105            Above-7  Below Average
# 106            Under-7        Average
# 107            Under-7  Above Average
# 109            Under-7        Average
# 111            Under-7        Average
# 112            Above-7  Below Average
# 113            Above-7  Below Average
# 114            Above-7  Below Average
# 115            Above-7  Below Average
# 116            Above-7        Average
# 117            Under-7  Above Average
# 118            Above-7        Average
# 119            Under-7        Average
# 120            Under-7        Average
# 121            Above-7  Below Average
# 122            Above-7        Average
# 124            Under-7  Below Average
# 125            Above-7  Below Average
# 127            Above-7  Below Average
# 128            Under-7  Below Average
# 129            Under-7  Below Average
# 130            Above-7  Below Average
# 132            Above-7  Below Average
# 133            Above-7  Below Average
# 249            Above-7        Average

# %%
'''Grab the count to display gender distribution'''

count_student_male = len(it.loc[it["Gender"]=="M"])
count_student_female = len(it) - count_student_male

# %%
'''Gender distribution for Kuwait IT primary school'''

student_count = [count_student_male, count_student_female]
labels = ["Male ("+ str(count_student_male)+")", "Female ("+ str(count_student_female)+")"]
colors = ["dodgerblue", "pink"]

fig, ax = plt.subplots(figsize=(6,6))

patches, texts, pcts = ax.pie ( 
    student_count, labels=labels, autopct="%.1f%%", 
    wedgeprops={"linewidth": 3.0, "edgecolor": "white"},
    textprops={"size": "x-large"},
    startangle=200, 
    shadow = True,
    colors = colors)

ax.set_title("Kuwait PrimarySchool IT Gender Distribution", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Kuwait PrimarySchool IT Gender Distribution')

# %%
'''Separated Columns by Gender and Performance Category'''

Male_Below_Average = it.loc[(it["Gender"]== "M") & (it["Performance"]=="Below Average")]
Male_Average = it.loc[(it["Gender"]== "M") & (it["Performance"]=="Average")]
Male_Above_Average = it.loc[(it["Gender"]== "M") & (it["Performance"]=="Above Average")]

Female_Below_Average = it.loc[(it["Gender"]== "F") & (it["Performance"]=="Below Average")]
Female_Average = it.loc[(it["Gender"]== "F") & (it["Performance"]=="Average")]
Female_Above_Average = it.loc[(it["Gender"]== "F") & (it["Performance"]=="Above Average")]

# %%
'''Collected Individual Averages of columns in order to graph'''

MB_Raised_Hand_Avg = (sum(Male_Below_Average["RaisedHand"].to_numpy())) / len(Male_Below_Average["RaisedHand"].to_numpy())
MB_Visited_Res_Avg = (sum(Male_Below_Average["VisitedResources"].to_numpy()) / len(Male_Below_Average["VisitedResources"].to_numpy()))
MB_Discussion_Avg = (sum(Male_Below_Average["Discussion"].to_numpy())) / len(Male_Below_Average["Discussion"].to_numpy())

FB_Raised_Hand_Avg = (sum(Female_Below_Average["RaisedHand"].to_numpy())) / len(Female_Below_Average["RaisedHand"].to_numpy())
FB_Visited_Res_Avg = (sum(Female_Below_Average["VisitedResources"].to_numpy()) / len(Female_Below_Average["VisitedResources"].to_numpy()))
FB_Discussion_Avg = (sum(Female_Below_Average["Discussion"].to_numpy())) / len(Female_Below_Average["Discussion"].to_numpy())

# %%
'''Data Collection'''

below_male_data = [MB_Raised_Hand_Avg, MB_Visited_Res_Avg, MB_Discussion_Avg]
below_female_data = [FB_Raised_Hand_Avg, FB_Visited_Res_Avg, FB_Discussion_Avg]

below_average_students = it.loc[it["Performance"] == "Below Average"]
attendance = Counter(below_average_students["StudentAbsenceDays"])
absences = ["Under 7 Days", "Above 7 Days"]
counts = [attendance["Under-7"], attendance["Above-7"]]

# %%
'''Graph Data For Below Average Students Behavior Frequencies'''

groups = 3

fig, ax = plt.subplots()
index = np.arange(groups)
bar_width = .35
opacity = .8

first_rect = plt.bar(index, below_male_data, bar_width,
                     alpha = opacity,
                     color = "black",
                     label = "Male")

second_rect = plt.bar(index + bar_width, below_female_data, bar_width,
                     alpha = opacity,
                     color = "pink",
                     label = "Female")

plt.xlabel("Activity")
plt.ylabel("AVG Occurences of Behavior (100)")
plt.title("Below Average Student Behavior Frequencies")
plt.xticks(index + bar_width, ('Raised Hand', 'Visited Resources', 'Discussion Participation'))
plt.ylim([0, 100])
plt.legend()
plt.tight_layout()

# %%
'''Attendance Behaviors in Average Performing Students'''

plt.title("Attendance in Below Average Performing Students")
plt.barh(absences, counts, color=["Green", "Red"])
plt.xlim([0, 54])
plt.xlabel("Frequency")
for index, value in enumerate(counts):
    plt.text(value, index, str(value))

# %%
'''Data Averages Calculated for above Average performing students'''

MA_Raised_Hand_Avg = (sum(Male_Above_Average["RaisedHand"].to_numpy())) / len(Male_Above_Average["RaisedHand"].to_numpy())
MA_Visited_Res_Avg = (sum(Male_Above_Average["VisitedResources"].to_numpy()) / len(Male_Above_Average["VisitedResources"].to_numpy()))
MA_Discussion_Avg = (sum(Male_Above_Average["Discussion"].to_numpy())) / len(Male_Above_Average["Discussion"].to_numpy())

FA_Raised_Hand_Avg = (sum(Female_Above_Average["RaisedHand"].to_numpy())) / len(Female_Above_Average["RaisedHand"].to_numpy())
FA_Visited_Res_Avg = (sum(Female_Above_Average["VisitedResources"].to_numpy()) / len(Female_Above_Average["VisitedResources"].to_numpy()))
FA_Discussion_Avg = (sum(Female_Above_Average["Discussion"].to_numpy())) / len(Female_Above_Average["Discussion"].to_numpy())

# %%
'''Data organized and attendance behavior recorded for displaying'''

above_male_data = [MA_Raised_Hand_Avg, MA_Visited_Res_Avg, MA_Discussion_Avg]
above_female_data = [FA_Raised_Hand_Avg, FA_Visited_Res_Avg, FA_Discussion_Avg]

above_average_students = it.loc[it["Performance"] == "Above Average"]

attendance = Counter(above_average_students["StudentAbsenceDays"])
absences = ["Under 7 Days", "Above 7 Days"]
counts = [attendance["Under-7"], attendance["Above-7"]]

# %%
'''Graph Data For Above Average Students Behavior Frequencies'''

groups = 3

fig, ax = plt.subplots()
index = np.arange(groups)
bar_width = .35
opacity = .8

first_rect = plt.bar(index, above_male_data, bar_width,
                     alpha = opacity,
                     color = "black",
                     label = "Male")

second_rect = plt.bar(index + bar_width, above_female_data, bar_width,
                     alpha = opacity,
                     color = "pink",
                     label = "Female")

plt.xlabel("Activity")
plt.ylabel("AVG Occurences of Behavior (100)")
plt.title("Above Average Student Behavior Frequencies")
plt.xticks(index + bar_width, ('Raised Hand', 'Visited Resources', 'Discussion Participation'))
plt.ylim([0, 100])
plt.legend()
plt.tight_layout()

# %%
'''Attendance Behavior in Above Average Performace Students'''

plt.title("Attendance in Above Average Performing Students")
plt.barh(absences, counts, color=["Green", "Red"])
plt.xlim([0, 8])
plt.xlabel("Student Frequency")
for index, value in enumerate(counts):
    plt.text(value, index, str(value))

# %%
'''Ensure Sample Size of Primary Students in Kuwait'''

len(it)
# Out:
# 54

# %%
'''We Begin Our Regression Analysis by selecting the most relevant Independent Variables to the hypothesis. Models Will be 
   created to test hypothesis that student behavior/performance is positively correlated by parental involvment in academics 
   and that actively participating students will outperform students who do not engage actively.'''

it_regression_data = it[["Gender", "PrimaryGuardian", 
                         "ParentAnsweringSurvey", "RaisedHand", 
                         "VisitedResources", "AnnouncementsView", 
                         "Discussion", "StudentAbsenceDays", "Performance"]]

it_regression_data
# Out:
#     Gender PrimaryGuardian ParentAnsweringSurvey  RaisedHand  \
# 0        M          Father                   Yes          15
# 1        M          Father                   Yes          20
# 2        M          Father                    No          10
# 3        M          Father                    No          30
# 4        M          Father                    No          40
# 5        F          Father                   Yes          42
# 12       M          Father                    No           5
# 81       M          Father                    No           8
# 82       M          Father                   Yes           7
# 83       M          Father                    No           7
# 84       M          Father                   Yes          50
# 85       M          Father                    No           1
# 87       M          Father                    No          19
# 88       F          Father                    No           3
# 89       M          Father                   Yes           5
# 90       M          Father                   Yes           4
# 91       M          Father                   Yes          80
# 92       F          Father                   Yes          50
# 94       F          Father                    No          80
# 95       F          Father                    No         100
# 96       F          Father                   Yes          14
# 97       F          Father                    No           6
# 98       F          Father                    No          10
# 99       M          Father                   Yes          50
# 100      M          Father                   Yes          50
# 101      F          Mother                   Yes          70
# 102      F          Father                    No           2
# 103      M          Father                    No           1
# 104      M          Father                   Yes           0
# 105      F          Father                   Yes           0
# 106      F          Father                   Yes          12
# 107      M          Father                   Yes          70
# 109      M          Father                    No          90
# 111      M          Father                    No          77
# 112      M          Father                    No           2
# 113      M          Father                    No          25
# 114      M          Father                    No          11
# 115      M          Father                   Yes           0
# 116      F          Mother                   Yes          77
# 117      F          Mother                    No          25
# 118      F          Mother                   Yes          24
# 119      M          Father                    No          60
# 120      M          Mother                   Yes          21
# 121      M          Mother                    No           0
# 122      F          Father                   Yes          66
# 124      M          Father                   Yes           0
# 125      M          Father                    No          12
# 127      M          Father                    No          55
# 128      M          Father                    No          12
# 129      M          Father                   Yes          70
# 130      F          Father                    No           7
# 132      M          Father                    No           0
# 133      M          Father                   Yes          12
# 249      M          Father                    No          65
#
#      VisitedResources  AnnouncementsView  Discussion StudentAbsenceDays  \
# 0                  16                  2          20            Under-7
# 1                  20                  3          25            Under-7
# 2                   7                  0          30            Above-7
# 3                  25                  5          35            Above-7
# 4                  50                 12          50            Above-7
# 5                  30                 13          70            Above-7
# 12                  1                  0          11            Above-7
# 81                 25                  1          70            Above-7
# 82                  5                  2          80            Above-7
# 83                  4                 10          50            Above-7
# 84                 70                 50          10            Above-7
# 85                  0                  1          12            Above-7
# 87                 70                  3          50            Under-7
# 88                 12                  4          33            Under-7
# 89                 20                  1          50            Above-7
# 90                  8                 10          60            Above-7
# 91                 90                 55          19            Under-7
# 92                 70                 19          15            Under-7
# 94                 44                 35          10            Above-7
# 95                 80                  2          70            Under-7
# 96                 60                 11          75            Under-7
# 97                  2                 38          12            Under-7
# 98                  3                  0          30            Under-7
# 99                  7                  9          50            Above-7
# 100                90                 40          90            Under-7
# 101                92                 50           7            Under-7
# 102                 6                  2           8            Above-7
# 103                 7                  6          10            Above-7
# 104                12                  3           3            Above-7
# 105                 0                  5          80            Above-7
# 106                26                  7          40            Under-7
# 107                90                 41          33            Under-7
# 109                70                 30          14            Under-7
# 111                80                 51          80            Under-7
# 112                 5                  3          50            Above-7
# 113                27                  0          69            Above-7
# 114                 2                  0          50            Above-7
# 115                 8                 11          70            Above-7
# 116                80                 12          19            Above-7
# 117                29                 40          17            Under-7
# 118                35                 23          22            Above-7
# 119                60                  3          60            Under-7
# 120                12                  0          50            Under-7
# 121                 4                  8          30            Above-7
# 122                90                 55          12            Above-7
# 124                 6                  4          15            Under-7
# 125                30                  0          17            Above-7
# 127                33                  6           9            Above-7
# 128                10                 20          16            Under-7
# 129                90                  2           2            Under-7
# 130                 9                  5          30            Above-7
# 132                 3                 10           3            Above-7
# 133                60                  0          70            Above-7
# 249                86                 62          40            Above-7
#
#        Performance
# 0          Average
# 1          Average
# 2    Below Average
# 3    Below Average
# 4          Average
# 5          Average
# 12   Below Average
# 81   Below Average
# 82   Below Average
# 83         Average
# 84   Above Average
# 85   Below Average
# 87   Below Average
# 88   Below Average
# 89   Below Average
# 90   Below Average
# 91   Above Average
# 92   Above Average
# 94   Below Average
# 95   Above Average
# 96   Above Average
# 97         Average
# 98         Average
# 99         Average
# 100        Average
# 101  Above Average
# 102  Below Average
# 103  Below Average
# 104        Average
# 105  Below Average
# 106        Average
# 107  Above Average
# 109        Average
# 111        Average
# 112  Below Average
# 113  Below Average
# 114  Below Average
# 115  Below Average
# 116        Average
# 117  Above Average
# 118        Average
# 119        Average
# 120        Average
# 121  Below Average
# 122        Average
# 124  Below Average
# 125  Below Average
# 127  Below Average
# 128  Below Average
# 129  Below Average
# 130  Below Average
# 132  Below Average
# 133  Below Average
# 249        Average

# %%
'''We single out our dependent variable "Performance" (catorgical), and use the pd.dummies command to convert it into numeric
   instead of Above AVG, Average, Below AVG, it is now Below Average or Not for the purpose of this analysis.'''

w = it_regression_data.loc[:, "Performance"]
performance_col= pd.get_dummies(w, drop_first=True)
performance_col = performance_col.loc[:, "Below Average"]


x = it_regression_data.drop("Performance", axis=1)
y = performance_col

# %%
'''We convert any independent categorical variables into numeric using the same method above. Also, student behavior frequency
   columns are turned into percents because it was measured out of 100. Columns are then renamed for clarity'''

x = pd.get_dummies(x, drop_first=True)

x["RaisedHand"] = x["RaisedHand"].div(100).round(2)
x["VisitedResources"] = x["VisitedResources"].div(100).round(2)
x["AnnouncementsView"] = x["AnnouncementsView"].div(100).round(2)
x["Discussion"] = x["Discussion"].div(100).round(2)

x.rename(columns={"Gender_M": "Gender_Male", 
                  "PrimaryGuardian_Mother": "Primary_Guardian_Mother", 
                  "ParentAnsweringSurvey_Yes": "GuardianAnsweredSurvey",
                  "StudentAbsenceDays_Under-7": "AbsencesUnder7Days"}, errors="raise")
# Out:
#      RaisedHand  VisitedResources  AnnouncementsView  Discussion  Gender_Male  \
# 0          0.15              0.16               0.02        0.20            1
# 1          0.20              0.20               0.03        0.25            1
# 2          0.10              0.07               0.00        0.30            1
# 3          0.30              0.25               0.05        0.35            1
# 4          0.40              0.50               0.12        0.50            1
# 5          0.42              0.30               0.13        0.70            0
# 12         0.05              0.01               0.00        0.11            1
# 81         0.08              0.25               0.01        0.70            1
# 82         0.07              0.05               0.02        0.80            1
# 83         0.07              0.04               0.10        0.50            1
# 84         0.50              0.70               0.50        0.10            1
# 85         0.01              0.00               0.01        0.12            1
# 87         0.19              0.70               0.03        0.50            1
# 88         0.03              0.12               0.04        0.33            0
# 89         0.05              0.20               0.01        0.50            1
# 90         0.04              0.08               0.10        0.60            1
# 91         0.80              0.90               0.55        0.19            1
# 92         0.50              0.70               0.19        0.15            0
# 94         0.80              0.44               0.35        0.10            0
# 95         1.00              0.80               0.02        0.70            0
# 96         0.14              0.60               0.11        0.75            0
# 97         0.06              0.02               0.38        0.12            0
# 98         0.10              0.03               0.00        0.30            0
# 99         0.50              0.07               0.09        0.50            1
# 100        0.50              0.90               0.40        0.90            1
# 101        0.70              0.92               0.50        0.07            0
# 102        0.02              0.06               0.02        0.08            0
# 103        0.01              0.07               0.06        0.10            1
# 104        0.00              0.12               0.03        0.03            1
# 105        0.00              0.00               0.05        0.80            0
# 106        0.12              0.26               0.07        0.40            0
# 107        0.70              0.90               0.41        0.33            1
# 109        0.90              0.70               0.30        0.14            1
# 111        0.77              0.80               0.51        0.80            1
# 112        0.02              0.05               0.03        0.50            1
# 113        0.25              0.27               0.00        0.69            1
# 114        0.11              0.02               0.00        0.50            1
# 115        0.00              0.08               0.11        0.70            1
# 116        0.77              0.80               0.12        0.19            0
# 117        0.25              0.29               0.40        0.17            0
# 118        0.24              0.35               0.23        0.22            0
# 119        0.60              0.60               0.03        0.60            1
# 120        0.21              0.12               0.00        0.50            1
# 121        0.00              0.04               0.08        0.30            1
# 122        0.66              0.90               0.55        0.12            0
# 124        0.00              0.06               0.04        0.15            1
# 125        0.12              0.30               0.00        0.17            1
# 127        0.55              0.33               0.06        0.09            1
# 128        0.12              0.10               0.20        0.16            1
# 129        0.70              0.90               0.02        0.02            1
# 130        0.07              0.09               0.05        0.30            0
# 132        0.00              0.03               0.10        0.03            1
# 133        0.12              0.60               0.00        0.70            1
# 249        0.65              0.86               0.62        0.40            1
#
#      Primary_Guardian_Mother  GuardianAnsweredSurvey  AbsencesUnder7Days
# 0                          0                       1                   1
# 1                          0                       1                   1
# 2                          0                       0                   0
# 3                          0                       0                   0
# 4                          0                       0                   0
# 5                          0                       1                   0
# 12                         0                       0                   0
# 81                         0                       0                   0
# 82                         0                       1                   0
# 83                         0                       0                   0
# 84                         0                       1                   0
# 85                         0                       0                   0
# 87                         0                       0                   1
# 88                         0                       0                   1
# 89                         0                       1                   0
# 90                         0                       1                   0
# 91                         0                       1                   1
# 92                         0                       1                   1
# 94                         0                       0                   0
# 95                         0                       0                   1
# 96                         0                       1                   1
# 97                         0                       0                   1
# 98                         0                       0                   1
# 99                         0                       1                   0
# 100                        0                       1                   1
# 101                        1                       1                   1
# 102                        0                       0                   0
# 103                        0                       0                   0
# 104                        0                       1                   0
# 105                        0                       1                   0
# 106                        0                       1                   1
# 107                        0                       1                   1
# 109                        0                       0                   1
# 111                        0                       0                   1
# 112                        0                       0                   0
# 113                        0                       0                   0
# 114                        0                       0                   0
# 115                        0                       1                   0
# 116                        1                       1                   0
# 117                        1                       0                   1
# 118                        1                       1                   0
# 119                        0                       0                   1
# 120                        1                       1                   1
# 121                        1                       0                   0
# 122                        0                       1                   0
# 124                        0                       1                   1
# 125                        0                       0                   0
# 127                        0                       0                   0
# 128                        0                       0                   1
# 129                        0                       1                   1
# 130                        0                       0                   0
# 132                        0                       0                   0
# 133                        0                       1                   0
# 249                        0                       0                   0

# %%
'''Cov_Pearsons(X, Y) Function finds the covariance and pearsons r correlation value in order to assess linear relationships'''

def cov_pearsons(x, y): 
    covariance = np.cov(x, y)
    pearsons = stats.pearsonr(x, y)
    
    print("Covariance:", covariance[0][1])
    print("Pearsons R Correlation:", pearsons[0])
    print("P-Value:", pearsons[1])
    
    if pearsons[1] <= .05:
        print("Statistically Significant")
    else: print("Not Statistically Significant, Support Null")
    
    print()

# %%
'''For Loop iterates through list of column names and passes it through our Cov_Pearsons(X, Y) Function'''

for names in x.columns: 
    print("Covariance and Pearsons R For Column: " +names + " to Performance")
    cov_pearsons(x[names], y)
# Out:
# Covariance and Pearsons R For Column: RaisedHand to Performance
# Covariance: -0.07641509433962264
# Pearsons R Correlation: -0.5148136397676649
# P-Value: 6.809434208206233e-05
# Statistically Significant
#
# Covariance and Pearsons R For Column: VisitedResources to Performance
# Covariance: -0.0789622641509434
# Pearsons R Correlation: -0.4843385865679688
# P-Value: 0.00020645449535088183
# Statistically Significant
#
# Covariance and Pearsons R For Column: AnnouncementsView to Performance
# Covariance: -0.04688679245283019
# Pearsons R Correlation: -0.5147495978520339
# P-Value: 6.826087499610338e-05
# Statistically Significant
#
# Covariance and Pearsons R For Column: Discussion to Performance
# Covariance: -0.0012264150943396264
# Pearsons R Correlation: -0.009631698883518731
# P-Value: 0.9448911746041039
# Not Statistically Significant, Support Null
#
# Covariance and Pearsons R For Column: Gender_M to Performance
# Covariance: 0.0660377358490566
# Pearsons R Correlation: 0.27910827799011495
# P-Value: 0.04096932616937743
# Statistically Significant
#
# Covariance and Pearsons R For Column: PrimaryGuardian_Mother to Performance
# Covariance: -0.037735849056603765
# Pearsons R Correlation: -0.23570226039551578
# P-Value: 0.08620060318762995
# Not Statistically Significant, Support Null
#
# Covariance and Pearsons R For Column: ParentAnsweringSurvey_Yes to Performance
# Covariance: -0.08490566037735854
# Pearsons R Correlation: -0.33425160871869336
# P-Value: 0.013501156291678567
# Statistically Significant
#
# Covariance and Pearsons R For Column: StudentAbsenceDays_Under-7 to Performance
# Covariance: -0.11320754716981128
# Pearsons R Correlation: -0.4522670168666453
# P-Value: 0.0005961129792154009
# Statistically Significant

# %%
'''Kuwait Primary School IT Student Correlation Matrix'''
corrmatrix = x.corr()
plt.figure(num=None, figsize=(len(x.columns), len(x.columns)), dpi=80, facecolor='w', edgecolor="k")
matrix = plt.matshow(corr, fignum=1)
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.gca().xaxis.tick_bottom() 
plt.colorbar(matrix)
plt.title("Kuwait Primary School IT Student Correlation Matrix")
plt.show()

# %%
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
# 5      0
# 12     1
# 81     1
# 82     1
# 83     0
# 84     0
# 85     1
# 87     1
# 88     1
# 89     1
# 90     1
# 91     0
# 92     0
# 94     1
# 95     0
# 96     0
# 97     0
# 98     0
# 99     0
# 100    0
# 101    0
# 102    1
# 103    1
# 104    0
# 105    1
# 106    0
# 107    0
# 109    0
# 111    0
# 112    1
# 113    1
# 114    1
# 115    1
# 116    0
# 117    0
# 118    0
# 119    0
# 120    0
# 121    1
# 122    0
# 124    1
# 125    1
# 127    1
# 128    1
# 129    1
# 130    1
# 132    1
# 133    1
# 249    0
# Name: Below Average, dtype: uint8
